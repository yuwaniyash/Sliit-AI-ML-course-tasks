# %% [markdown]
# <a href="https://colab.research.google.com/github/yuwaniyash/Sliit-AI-ML-course-tasks/blob/main/Mobile-Price-Classification/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Mobile_Prices.csv')
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# # Feature Extraction

# %%
X = df.drop('price_range',axis=1)
Y = df['price_range']

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25,random_state=42)

# %% [markdown]
# # Building Ann with 2 hidden layers

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(8, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Compiling the model

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Scaling Data(Additional)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Train the model(100 epochs,batch size 32)

# %%
model.fit(X_train, Y_train,
          epochs=100,
          batch_size=32,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4847 - loss: 0.7089 - val_accuracy: 0.4940 - val_loss: 0.7068
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5160 - loss: 0.6995 - val_accuracy: 0.5200 - val_loss: 0.6999
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5267 - loss: 0.6952 - val_accuracy: 0.5180 - val_loss: 0.6966
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5493 - loss: 0.6925 - val_accuracy: 0.5280 - val_loss: 0.6940
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5607 - loss: 0.6899 - val_accuracy: 0.5400 - val_loss: 0.6918
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5773 - loss: 0.6866 - val_accuracy: 0.5460 - val_loss: 0.6890
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5900 - loss: 0.6831 - val_accuracy: 0.5520 - val_loss: 0.6855
# Epoch 8/100
# ...

# %% [markdown]
# # Saving the weights

# %%
model.save_weights('mobile_price_weights.weights.h5')

# %% [markdown]
# # Evaluation

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7500 - loss: 0.4926
# Accuracy: 75.00%
